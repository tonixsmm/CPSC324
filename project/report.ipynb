# %% [markdown]
# # CPSC 324 Big Data Analysis
# ## Final Project

# %%
from data_cleaning import *
from translator import *
# Out:
# [nltk_data] Downloading package stopwords to /Users/tony/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = load_file('biden_cleaned.csv')

# %%
df.head(10)
# Out:
#                                                tweet  likes  retweet_count
# 0  @ddale8 vote wisely. and by wisely i mean for ...     17              2
# 1  alguém ainda acredita em pesquisas? a história...     25              1
# 2  too little too late? twitter announces ‘hacked...     44             22
# 3  tonight #biden was president  he answered ques...    476            194
# 4  buongiorno ricordo che stasera ore 20.oo ci in...     19              9
# 5  i repeat, if you''re voting for senile #biden ...     11              1
# 6  armenia is #ganjacity  and #mingachevir contin...     18             13
# 7  @therickwilson just another one of t''s mouthp...     80             32
# 8  #joebiden hat gelogen. klar hatte der ""man of...     49             24
# 9  gaat reactie #biden op vraag van @realdonaldtr...     18              7

# %%
# for row in df['tweet']:
#     process_text(row)
# Out:
# Detected language: en
# Detected language: pt
# Translating text to English for analysis...
# Detected language: en
# Detected language: en
# Detected language: it
# Translating text to English for analysis...
# Detected language: en
# Detected language: en
# Detected language: en
# Detected language: de
# Translating text to English for analysis...
# Detected language: nl
# Translating text to English for analysis...
# Detected language: en
# Detected language: en
# Detected language: en
# Detected language: en
# Detected language: en
# Detected language: en
# Detected language: es
# Translating text to English for analysis...
# Detected language: en
# Detected language: en
# Detected language: en
# Detected language: en
# Detected language: de
# Translating text to English for analysis...
# Detected language: en
# Detected language: en
# Detected language: de
# Translating text to English for analysis...
# Detected language: en
# Detected language: en
# Detected language: de
# ...
